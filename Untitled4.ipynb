# %%
import os
path = "/content/sample_data"
os.chdir(path)

# %%
# !python data_process.py

# %%
# !python my_model.py

# %%
# !python train_model_main.py

# %%
# !python run_model.py

# %%
import matplotlib.pyplot as plt
import run_model
real_data,pre_data = run_model.real_data,run_model.pre_data
plt.plot(pre_data, color='red', label="pre_price")
plt.plot(real_data, color='blue', label="real_price")
plt.title("stoce_price_forecast")
plt.xlabel('Trading_Day')
plt.ylabel('Price')
print("预测效果图绘制完毕！")
plt.legend()
plt.show()
# Out:
# 预测效果图绘制完毕！

# %%
import run_modedl as rl

def show_loss(history):
    """loss可视化"""
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('train and val loss')
    plt.legend()
    plt.show()
show_loss(rl.history)
